# %% [markdown]
# # Cleaning input raw data

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.window import Window
from dateutil import parser
from pyspark.sql.functions import udf
from pyspark.sql.types import DateType, StringType

# %%
spark = SparkSession.builder.appName("Data Cleaning").master("local[*]").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://V:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Data Cleaning</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
input_df = spark.read.option("header", "true").option("inferSchema", "true").format("csv").load("../input/messy_ecommerce_1K.csv")
input_df.show(10)
# Out:
# +--------------------+----------------+----------+------------+-------------+-----------+--------------------+-------------------+------------------+--------------+------------+---------------+--------------------------+-------------+--------------+----------+--------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------+--------------------+--------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+
# |            order_id|      order_date|order_time|order_status|shipping_cost|customer_id|      customer_email|customer_first_name|customer_last_name|customer_phone|customer_age|customer_gender|customer_registration_date|customer_city|customer_state|product_id|        product_name|product_category|product_subcategory| product_brand|product_cost|product_list_price|warehouse_id|warehouse_city|warehouse_state|warehouse_country|quantity_ordered|unit_price|line_total|discount_amount|discount_percent|coupon_code|      payment_method|payment_status|order_returned|payment_refunded|shipping_address_line1|shipping_address_line2|shipping_city|shipping_state|shipping_zip|shipping_country|shipping_method|
# +--------------------+----------------+----------+------------+-------------+-----------+--------------------+-------------------+------------------+--------------+------------+---------------+--------------------------+-------------+--------------+----------+--------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------+--------------------+--------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+
# |25de4eb1-5097-4cd...|      2024/02/28|  21:55:59|     pending|          1.6|  CUST_0497|christopher.campb...|        Christopher|          Campbell|(228) 832-9907|          63|              M|                2022/04/11|      Seattle|            WA|   PRD_492|        Nestle Spice|    Groceries   |             Spices|        Nestle|        15.6|             22.89|      WH_019|       Houston|             TX|               US|               5|     19.09|     95.45|           NULL|            NULL|       NULL|              paypal|       pending|            no|               0|        6115 Cedar Ave|                  NULL|      Seattle|            WA|       ABCDE|              US|        express|
# |699d9092-8c9c-4cd...|     05-Feb-2024|  07:30:19|     pending|         7.35|  CUST_0400|joseph.roberts@gm...|             Joseph|           Roberts|  785-591-1414|          45|              F|               20-Oct-2023|     New York|            NY|   PRD_399|Puma Recovery Cla...|          Sports|           Recovery|          Puma|      312.27|            540.22|      WH_005|      New York|             NY|               US|               8|    603.12|   4824.96|           28.8|             6.4|     save14|          google_pay|       pending|           yes|            true|                  NULL|            Apt 592   |     New York|            NY|       10014|              US|      overnight|
# |62f6661c-8451-4a2...|    Jan 15, 2024|  22:02:32|   cancelled|         3.59|  CUST_0852|paul.johnson@gmai...|               Paul|           Johnson|  664-849-6867|          49|              F|                2023/05/18|   Fort Worth|            TX|   PRD_129|          H&M Dresse|         Apparel|            Dresses|           H&M|      140.25|            226.78|      WH_020|       Houston|             TX|               US|               1|    193.42|    193.42|           31.0|            13.2|     SAVE50|credit_card|credi...|        failed|           yes|             yes|       1682 Second Ave|               Apt 439|   Fort Worth|            TX|       76110|              US|       standard|
# |d1a16214-f420-45b...|     25-Mar-2024|  16:51:36|     pending|         6.92|  CUST_0498|christopher.mitch...|        Christopher|          Mitchell|  445.868.4633|          34|          Other|         November 03, 2022|  Los Angeles|            CA|   prd_043|     Sony Tablet Pro|     Electronics|            Tablets|          Sony|      130.95|            200.71|      WH_050|      San Jose|             CA|               US|               1|    214.79|    214.79|          41.54|             0.3|     SAzE47|         credit_card|       pending|       pending|         pending|          4430 Oak Ave|                  NULL|  Los Angeles|            CA|        NULL|              US|       standard|
------+-------------+-----------+--------------------+-------------------+------------------+--------------+------------+---------------+--------------------------+-------------+--------------+----------+--------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------+--------------------+--------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+
# only showing top 10 rows

# %%
print(f"Number of rows: {input_df.count()}")
print(f"Number of columns: {len(input_df.columns)}")
print(f"Column names: {input_df.columns}")
# Out:
# Number of rows: 1000
# Number of columns: 43
# Column names: ['order_id', 'order_date', 'order_time', 'order_status', 'shipping_cost', 'customer_id', 'customer_email', 'customer_first_name', 'customer_last_name', 'customer_phone', 'customer_age', 'customer_gender', 'customer_registration_date', 'customer_city', 'customer_state', 'product_id', 'product_name', 'product_category', 'product_subcategory', 'product_brand', 'product_cost', 'product_list_price', 'warehouse_id', 'warehouse_city', 'warehouse_state', 'warehouse_country', 'quantity_ordered', 'unit_price', 'line_total', 'discount_amount', 'discount_percent', 'coupon_code', 'payment_method', 'payment_status', 'order_returned', 'payment_refunded', 'shipping_address_line1', 'shipping_address_line2', 'shipping_city', 'shipping_state', 'shipping_zip', 'shipping_country', 'shipping_method']

# %% [markdown]
# ### Cleaning order status

# %%
raw_order_status = input_df.select("order_status").distinct().rdd.flatMap(lambda x: x).collect()
print(raw_order_status)

order_status_lookup = spark.read.option("header", "true").option("inferSchema", True).format("csv").load("../lookup/order_status.csv")
# order_status_lookup.show()

clean_order_status_df = input_df.withColumn("order_status", trim(lower(col("order_status"))))

clean_order_status_df = clean_order_status_df.join(
    order_status_lookup, 
    on=clean_order_status_df.order_status==order_status_lookup.raw_status,
    how="left").withColumn("order_status_cleaned", coalesce(col("clean_status"), lit("pending"))).drop("order_status", "raw_status", "clean_status")

cleaned_order_status = clean_order_status_df.select("order_status_cleaned").distinct().rdd.flatMap(lambda x: x).collect()
print(cleaned_order_status)

clean_order_status_df.show()
# Out:
# ['pending|pending_alt', 'cancelled   ', 'deliveryd', 'shipped', '  pending  ', '  shipped  ', 'cancelled', 'pxnding', 'cancelled|cancelled_alt', 'shipped   ', 'DELIVERED', 'cancel3ed', 'CANCELLED', 'delivered', 'pending', 'cancexled', 'shxpped', 'shippxd', 'pending   ', 'PENDING', 'pexding', None]
# +--------------------+-----------------+--------------------+-------------+-----------+--------------------+-------------------+------------------+--------------+------------+---------------+--------------------------+-------------------+--------------+----------+--------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------------+--------------------+--------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+--------------------+
# |            order_id|       order_date|          order_time|shipping_cost|customer_id|      customer_email|customer_first_name|customer_last_name|customer_phone|customer_age|customer_gender|customer_registration_date|      customer_city|customer_state|product_id|        product_name|product_category|product_subcategory| product_brand|product_cost|product_list_price|warehouse_id|warehouse_city|warehouse_state|warehouse_country|quantity_ordered|unit_price|line_total|discount_amount|discount_percent|      coupon_code|      payment_method|payment_status|order_returned|payment_refunded|shipping_address_line1|shipping_address_line2|shipping_city|shipping_state|shipping_zip|shipping_country|shipping_method|order_status_cleaned|
# +--------------------+-----------------+--------------------+-------------+-----------+--------------------+-------------------+------------------+--------------+------------+---------------+--------------------------+-------------------+--------------+----------+--------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------------+--------------------+--------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+--------------------+
# |25de4eb1-5097-4cd...|       2024/02/28|            21:55:59|          1.6|  CUST_0497|christopher.campb...|        Christopher|          Campbell|(228) 832-9907|          63|              M|                2022/04/11|            Seattle|            WA|   PRD_492|        Nestle Spice|    Groceries   |             Spices|        Nestle|        15.6|             22.89|      WH_019|       Houston|             TX|               US|               5|     19.09|     95.45|           NULL|            NULL|             NULL|              paypal|       pending|            no|               0|        6115 Cedar Ave|                  NULL|      Seattle|            WA|       ABCDE|              US|        express|             pending|
------+--------------------+-------------+-----------+--------------------+-------------------+------------------+--------------+------------+---------------+--------------------------+-------------------+--------------+----------+--------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------------+--------------------+--------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Clean dates - transforming dates data to standard form

# %%
def transform_date_udf(val):
    if val is None:
        return None
    return parser.parse(val).date()

transform_date_udf = udf(transform_date_udf, DateType())

clean_dates_df = clean_order_status_df.withColumn(
    "order_date_cleaned",
    transform_date_udf(col("order_date"))
).withColumn(
    "customer_registration_date_cleaned", 
    transform_date_udf(col("customer_registration_date"))
    ).drop("order_date", "customer_registration_date")
clean_dates_df.show()
# Out:
# +--------------------+--------------------+-------------+-----------+--------------------+-------------------+------------------+--------------+------------+---------------+-------------------+--------------+----------+--------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------------+--------------------+--------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+--------------------+------------------+----------------------------------+
# |            order_id|          order_time|shipping_cost|customer_id|      customer_email|customer_first_name|customer_last_name|customer_phone|customer_age|customer_gender|      customer_city|customer_state|product_id|        product_name|product_category|product_subcategory| product_brand|product_cost|product_list_price|warehouse_id|warehouse_city|warehouse_state|warehouse_country|quantity_ordered|unit_price|line_total|discount_amount|discount_percent|      coupon_code|      payment_method|payment_status|order_returned|payment_refunded|shipping_address_line1|shipping_address_line2|shipping_city|shipping_state|shipping_zip|shipping_country|shipping_method|order_status_cleaned|order_date_cleaned|customer_registration_date_cleaned|
# +--------------------+--------------------+-------------+-----------+--------------------+-------------------+------------------+--------------+------------+---------------+-------------------+--------------+----------+--------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------------+--------------------+--------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+--------------------+------------------+----------------------------------+
# |25de4eb1-5097-4cd...|            21:55:59|          1.6|  CUST_0497|christopher.campb...|        Christopher|          Campbell|(228) 832-9907|          63|              M|            Seattle|            WA|   PRD_492|        Nestle Spice|    Groceries   |             Spices|        Nestle|        15.6|             22.89|      WH_019|       Houston|             TX|               US|               5|     19.09|     95.45|           NULL|            NULL|             NULL|              paypal|       pending|            no|               0|        6115 Cedar Ave|                  NULL|      Seattle|            WA|       ABCDE|              US|        express|             pending|        2024-02-28|                        2022-04-11|
# |699d9092-8c9c-4cd...|            07:30:19|         7.35|  CUST_0400|joseph.roberts@gm...|             Joseph|           Roberts|  785-591-1414|          45|              F|           New York|            NY|   PRD_399|Puma Recovery Cla...|          Sports|           Recovery|          Puma|      312.27|            540.22|      WH_005|      New York|             NY|               US|               8|    603.12|   4824.96|           28.8|             6.4|           save14|          google_pay|       pending|           yes|            true|                  NULL|            Apt 592   |     New York|            NY|       10014|              US|      overnight|             pending|        2024-02-05|                        2023-10-20|
# |62f6661c-8451-4a2...|            22:02:32|         3.59|  CUST_0852|paul.johnson@gmai...|               Paul|           Johnson|  664-849-6867|          49|              F|         Fort Worth|            TX|   PRD_129|          H&M Dresse|         Apparel|            Dresses|           H&M|      140.25|            226.78|      WH_020|       Houston|             TX|               US|               1|    193.42|    193.42|           31.0|            13.2|           SAVE50|credit_card|credi...|        failed|           yes|             yes|       1682 Second Ave|               Apt 439|   Fort Worth|            TX|       76110|              US|       standard|              failed|        2024-01-15|                        2023-05-18|
# |d1a16214-f420-45b...|            16:51:36|         6.92|  CUST_0498|christopher.mitch...|        Christopher|          Mitchell|  445.868.4633|          34|          Other|        Los Angeles|            CA|   prd_043|     Sony Tablet Pro|     Electronics|            Tablets|          Sony|      130.95|            200.71|      WH_050|      San Jose|             CA|               US|               1|    214.79|    214.79|          41.54|             0.3|           SAzE47|         credit_card|       pending|       pending|         pending|          4430 Oak Ave|                  NULL|  Los Angeles|            CA|        NULL|              US|       standard|             pending|        2024-03-25|                        2022-11-03|
   PRD_485|Organic Valley Ba...|       Groceries|             Bakery|Organic Valley|       22.36|             33.03|      WH_008|   Los Angeles|             CA|               US|               9|     35.78|    322.02|          33.67|             1.7|         SAVE19  |           apple_pay|       pending|         false|               0|            203 Elm Dr|   Apt 670|Apt 670_alt|    San Diego|            CA|       92105|              US|        express|             pending|        2024-03-25|                        2023-04-17|
# |18297cb5-6506-499...|            03:50:18|         1.99|  CUST_0458|christopher.davis...|        Christopher|             Davis|    5515558928|          39|          Other|          Baltimore|            MD|   PRD_385|Spalding Nutritio...|          Sports|          Nutrition|      Spalding|      122.33|            190.83|      WH_010|   Los Angeles|             CA|               US|              10|    212.94|    2129.4|           9.39|         1.4.0.0|           SAVE43|              paypal|       pending|          true|            true|        6440 Cedar Ave|   Apt 991|Apt 991_alt|    Baltimore|            MD|       21204|              US|      overnight|             pending|        2024-03-07|                        2022-01-30|
# |15381d3d-6eef-4f7...|            11:56:26|         9.54|  CUST_0554|daniel.brown@gmai...|             Danizl|             Brown|  814-759-1082|          50|              M|            Seattle|            WA|   PRD_192|Puma Formal Wear ...|         Apparel|        Formal Wear|          Puma|       92.59|             160.5|      WH_005|      New York|             NY|               US|               9|    155.83|   1402.47|      10.08.0.0|             3.1|          SAVE6  |              paypal|        failed|       pending|         pending|          2591 Main St|                Apt 52|       Austin|            TX|       78704|              US|      overnight|             pending|        2024-02-08|                        2023-03-20|
# |f4498080-fc3a-43d...|            20:31:36|         5.99|  CUST_0852|paul.johnson@gmai...|               Paul|           Johnson|(734) 959-5169|          56|              F|        Los Angeles|            CA|   PRD_388|Nike Nutrition Pr...|          Sports|          Nutrition|          Nike|      228.37|             406.0|      WH_040|     San Diego|             CA|               US|              10|    469.13|    4691.3|          10.43|            10.5|           S@VE26|         credit_card|        failed|             1|               1|           4148 Elm Dr|               Apt 530|  Los Angeles|            CA|       90211|              US|      overnight|             pending|        2024-01-23|                        2023-01-01|
# +--------------------+--------------------+-------------+-----------+--------------------+-------------------+------------------+--------------+------------+---------------+-------------------+--------------+----------+--------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------------+--------------------+--------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+--------------------+------------------+----------------------------------+
# only showing top 20 rows

# %% [markdown]
# ### Transform phone number to standard format

# %%
cleaned_phone_number_df = clean_dates_df.withColumn(
    "customer_phone_cleaned", regexp_replace(col("customer_phone") , r"[^0-9]", "")
).withColumn(
    "customer_phone_cleaned", when(length(col("customer_phone_cleaned"))>10, col("customer_phone_cleaned").substr(2, 10)).otherwise(col("customer_phone_cleaned"))
).withColumn(
    "customer_phone_cleaned", concat(lit("("), col("customer_phone_cleaned").substr(1, 3), lit(")"), lit(" "), col("customer_phone_cleaned").substr(4, 3), lit("-"), col("customer_phone_cleaned").substr(7, 4))
).drop("customer_phone")
cleaned_phone_number_df.show()
# Out:
# +--------------------+--------------------+-------------+-----------+--------------------+-------------------+------------------+------------+---------------+-------------------+--------------+----------+--------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------------+--------------------+--------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+--------------------+------------------+----------------------------------+----------------------+
# |            order_id|          order_time|shipping_cost|customer_id|      customer_email|customer_first_name|customer_last_name|customer_age|customer_gender|      customer_city|customer_state|product_id|        product_name|product_category|product_subcategory| product_brand|product_cost|product_list_price|warehouse_id|warehouse_city|warehouse_state|warehouse_country|quantity_ordered|unit_price|line_total|discount_amount|discount_percent|      coupon_code|      payment_method|payment_status|order_returned|payment_refunded|shipping_address_line1|shipping_address_line2|shipping_city|shipping_state|shipping_zip|shipping_country|shipping_method|order_status_cleaned|order_date_cleaned|customer_registration_date_cleaned|customer_phone_cleaned|
# +--------------------+--------------------+-------------+-----------+--------------------+-------------------+------------------+------------+---------------+-------------------+--------------+----------+--------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------------+--------------------+--------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+--------------------+------------------+----------------------------------+----------------------+
# |25de4eb1-5097-4cd...|            21:55:59|          1.6|  CUST_0497|christopher.campb...|        Christopher|          Campbell|          63|              M|            Seattle|            WA|   PRD_492|        Nestle Spice|    Groceries   |             Spices|        Nestle|        15.6|             22.89|      WH_019|       Houston|             TX|               US|               5|     19.09|     95.45|           NULL|            NULL|             NULL|              paypal|       pending|            no|               0|        6115 Cedar Ave|                  NULL|      Seattle|            WA|       ABCDE|              US|        express|             pending|        2024-02-28|                        2022-04-11|        (228) 832-9907|
# |699d9092-8c9c-4cd...|            07:30:19|         7.35|  CUST_0400|joseph.roberts@gm...|             Joseph|           Roberts|          45|              F|           New York|            NY|   PRD_399|Puma Recovery Cla...|          Sports|           Recovery|          Puma|      312.27|            540.22|      WH_005|      New York|             NY|               US|               8|    603.12|   4824.96|           28.8|             6.4|           save14|          google_pay|       pending|           yes|            true|                  NULL|            Apt 592   |     New York|            NY|       10014|              US|      overnight|             pending|        2024-02-05|                        2023-10-20|        (785) 591-1414|
# |62f6661c-8451-4a2...|            22:02:32|         3.59|  CUST_0852|paul.johnson@gmai...|               Paul|           Johnson|          49|              F|         Fort Worth|            TX|   PRD_129|          H&M Dresse|         Apparel|            Dresses|           H&M|      140.25|            226.78|      WH_020|       Houston|             TX|               US|               1|    193.42|    193.42|           31.0|            13.2|           SAVE50|credit_card|credi...|        failed|           yes|             yes|       1682 Second Ave|               Apt 439|   Fort Worth|            TX|       76110|              US|       standard|              failed|        2024-01-15|                        2023-05-18|        (664) 849-6867|
# |d1a16214-f420-45b...|            16:51:36|         6.92|  CUST_0498|christopher.mitch...|        Christopher|          Mitchell|          34|          Other|        Los Angeles|            CA|   prd_043|     Sony Tablet Pro|     Electronics|            Tablets|          Sony|      130.95|            200.71|      WH_050|      San Jose|             CA|               US|               1|    214.79|    214.79|          41.54|             0.3|           SAzE47|         credit_card|       pending|       pending|         pending|          4430 Oak Ave|                  NULL|  Los Angeles|            CA|        NULL|              US|       standard|             pending|        2024-03-25|                        2022-11-03|        (445) 868-4633|
# |c07762d9-199c-422...|            19:09:07|         7.89|  CUST_0828|steven.ramirez@gm...|             Steven|           Ramirez|          53|              F|            Seattle|            WA|   PRD_237|Johnson Medical D...|      Healthcare|    Medical Devices|          NULL|       36.66|             58.52|      WH_043|        Dallas|             TX|               US|               8|     65.11|    520.88|          31.67|            14.8|           SAVE45|              paypal|       success|       pending|         pending|          8409 Park Rd|               Apt 455|      Seattle|            WA|       98107|              US|        express|             pending|        2024-01-03|                        2021-10-15|        (398) 748-5018|
# |1eb6539c-8f1b-463...|            14:11:10|         1.43|  CUST_0156|michael.garcia@gm...|            Michael|            Garcia|          59|          Other|            Chicago|            IL|   PRD_448|Organic Valley Be...|       Groceries|          Beverages|Organic Valley|       19.08|             24.25|      WH_014|       Chicago|             IL|               US|               3|     23.55|     70.65|            3.8|            23.1|           SAVE34|          debit_card|       success|       pending|         pending|         9521 First St|             Apt 257  |      Chicago|            IL|       60605|              US|        express|             success|        2024-01-09|                        2023-08-13|        (988) 466-1847|
# |15381d3d-6eef-4f7...|            11:56:26|         9.54|  CUST_0554|daniel.brown@gmai...|             Danizl|             Brown|          50|              M|            Seattle|            WA|   PRD_192|Puma Formal Wear ...|         Apparel|        Formal Wear|          Puma|       92.59|             160.5|      WH_005|      New York|             NY|               US|               9|    155.83|   1402.47|      10.08.0.0|             3.1|          SAVE6  |              paypal|        failed|       pending|         pending|          2591 Main St|                Apt 52|       Austin|            TX|       78704|              US|      overnight|             pending|        2024-02-08|                        2023-03-20|        (814) 759-1082|
# |f4498080-fc3a-43d...|            20:31:36|         5.99|  CUST_0852|paul.johnson@gmai...|               Paul|           Johnson|          56|              F|        Los Angeles|            CA|   PRD_388|Nike Nutrition Pr...|          Sports|          Nutrition|          Nike|      228.37|             406.0|      WH_040|     San Diego|             CA|               US|              10|    469.13|    4691.3|          10.43|            10.5|           S@VE26|         credit_card|        failed|             1|               1|           4148 Elm Dr|               Apt 530|  Los Angeles|            CA|       90211|              US|      overnight|             pending|        2024-01-23|                        2023-01-01|        (734) 959-5169|
# +--------------------+--------------------+-------------+-----------+--------------------+-------------------+------------------+------------+---------------+-------------------+--------------+----------+--------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------------+--------------------+--------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+--------------------+------------------+----------------------------------+----------------------+
# only showing top 20 rows

# %% [markdown]
# ### Clean payment status - map each payment status to 'success', 'failed' or 'pending'

# %%
raw_payment_status = cleaned_phone_number_df.select("payment_status").distinct().rdd.flatMap(lambda x: x).collect()
print(raw_order_status)

payment_status_lookup = spark.read.option("header", "true").option("inferSchema", "true").format("csv").load("../lookup/payment_status.csv")
payment_status_lookup.show(truncate=False)

cleaned_phone_number_df = cleaned_phone_number_df.withColumn("payment_status", trim(col("payment_status")))

cleaned_payment_status_df = cleaned_phone_number_df.join(
    broadcast(payment_status_lookup), 
    on=cleaned_phone_number_df.payment_status==payment_status_lookup.raw_value,
    how="left"
    ).withColumnRenamed(
        "standard_value", "payment_status_cleaned"
        ).drop("raw_value", "payment_status")

cleaned_payment_status_df.show(truncate=False)

cleaned_payment_status = cleaned_payment_status_df.select("payment_status_cleaned").distinct().rdd.flatMap(lambda x: x).collect()
print(cleaned_payment_status)
# Out:
# ['pending|pending_alt', 'cancelled   ', 'deliveryd', 'shipped', '  pending  ', '  shipped  ', 'cancelled', 'pxnding', 'cancelled|cancelled_alt', 'shipped   ', 'DELIVERED', 'cancel3ed', 'CANCELLED', 'delivered', 'pending', 'cancexled', 'shxpped', 'shippxd', 'pending   ', 'PENDING', 'pexding', None]
# +-------------------+--------------+
# |raw_value          |standard_value|
# +-------------------+--------------+
# |pending|pending_alt|pending       |
# |pending            |pending       |
# |pen@ing            |pending       |
# |penying            |pending       |
# |pen#ing            |pending       |
# |pendyng            |pending       |
# |pendxng            |pending       |
# |PENDING            |pending       |
# |success            |success       |
# |SUCCESS            |success       |
# |success|success_alt|success       |
# |succ@ss            |success       |
# |succexs            |success       |
# |failed             |failed        |
# |fail1d             |failed        |
# |fa@led             |failed        |
# |failed|failed_alt  |failed        |
# |NULL               |NULL          |
# +-------------------+--------------+
#
# +------------------------------------+---------------------+-------------+-----------+------------------------------+-------------------+------------------+------------+---------------+-------------------+--------------+----------+--------------------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------------+---------------------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+--------------------+------------------+----------------------------------+----------------------+----------------------+
# |order_id                            |order_time           |shipping_cost|customer_id|customer_email                |customer_first_name|customer_last_name|customer_age|customer_gender|customer_city      |customer_state|product_id|product_name                    |product_category|product_subcategory|product_brand |product_cost|product_list_price|warehouse_id|warehouse_city|warehouse_state|warehouse_country|quantity_ordered|unit_price|line_total|discount_amount|discount_percent|coupon_code      |payment_method             |order_returned|payment_refunded|shipping_address_line1|shipping_address_line2|shipping_city|shipping_state|shipping_zip|shipping_country|shipping_method|order_status_cleaned|order_date_cleaned|customer_registration_date_cleaned|customer_phone_cleaned|payment_status_cleaned|
# +------------------------------------+---------------------+-------------+-----------+------------------------------+-------------------+------------------+------------+---------------+-------------------+--------------+----------+--------------------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------------+---------------------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+--------------------+------------------+----------------------------------+----------------------+----------------------+
# |25de4eb1-5097-4cd3-a800-52b8a87e547e|21:55:59             |1.6          |CUST_0497  |christopher.campbell@gmail.com|Christopher        |Campbell          |63          |M              |Seattle            |WA            |PRD_492   |Nestle Spice                    |Groceries       |Spices             |Nestle        |15.6        |22.89             |WH_019      |Houston       |TX             |US               |5               |19.09     |95.45     |NULL           |NULL            |NULL             |paypal                     |no            |0               |6115 Cedar Ave        |NULL                  |Seattle      |WA            |ABCDE       |US              |express        |pending             |2024-02-28        |2022-04-11                        |(228) 832-9907        |pending               |
# |699d9092-8c9c-4cd5-a1dc-3a5e1f6b3c10|07:30:19             |7.35         |CUST_0400  |joseph.roberts@gmail.com      |Joseph             |Roberts           |45          |F              |New York           |NY            |PRD_399   |Puma Recovery Classic           |Sports          |Recovery           |Puma          |312.27      |540.22            |WH_005      |New York      |NY             |US               |8               |603.12    |4824.96   |28.8           |6.4             |save14           |google_pay                 |yes           |true            |NULL                  |Apt 592               |New York     |NY            |10014       |US              |overnight      |pending             |2024-02-05        |2023-10-20                        |(785) 591-1414        |pending               |
# |62f6661c-8451-4a2d-8e68-ee70fd920ae8|22:02:32             |3.59         |CUST_0852  |paul.johnson@gmail.com        |Paul               |Johnson           |49          |F              |Fort Worth         |TX            |PRD_129   |H&M Dresse                      |Apparel         |Dresses            |H&M           |140.25      |226.78            |WH_020      |Houston       |TX             |US               |1               |193.42    |193.42    |31.0           |13.2            |SAVE50           |credit_card|credit_card_alt|yes           |yes             |1682 Second Ave       |Apt 439               |Fort Worth   |TX            |76110       |US              |standard       |failed              |2024-01-15        |2023-05-18                        |(664) 849-6867        |failed                |
# |d1a16214-f420-45b1-8d86-0c8b3da45ffd|16:51:36             |6.92         |CUST_0498  |christopher.mitchell@gmail.com|Christopher        |Mitchell          |34          |Other          |Los Angeles        |CA            |prd_043   |Sony Tablet Pro                 |Electronics     |Tablets            |Sony          |130.95      |200.71            |WH_050      |San Jose      |CA             |US               |1               |214.79    |214.79    |41.54          |0.3             |SAzE47           |credit_card                |pending       |pending         |4430 Oak Ave          |NULL                  |Los Angeles  |CA            |NULL        |US              |standard       |pending             |2024-03-25        |2022-11-03                        |(445) 868-4633        |pending               |
# |c07762d9-199c-422c-b75f-38fe6a4699e2|19:09:07             |7.89         |CUST_0828  |steven.ramirez@gmail.com      |Steven             |Ramirez           |53          |F              |Seattle            |WA            |PRD_237   |Johnson Medical Device Deluxe   |Healthcare      |Medical Devices    |NULL          |36.66       |58.52             |WH_043      |Dallas        |TX             |US               |8               |65.11     |520.88    |31.67          |14.8            |SAVE45           |paypal                     |pending       |pending         |8409 Park Rd          |Apt 455               |Seattle      |WA            |98107       |US              |express        |pending             |2024-01-03        |2021-10-15                        |(398) 748-5018        |success               |
# |a7c8e3d9-83c1-47b0-add7-1e88810960ac|18:37:48             |4.47         |CUST_2284  |frank.kinggmail.com           |Frank              |King              |41          |NULL           |Austin             |TX            |PRD_182   |Levi Formal Wear Premium        |Apparel         |Formal Wear        |Levi          |52.66       |77.13             |WH_044      |dallas        |TX             |US               |10              |82.66     |826.6     |NULL           |20.2            |SAVE12           |paypal                     |false         |no              |3864 Second Ave       |Apt 350               |Austin       |TX            |78705       |US              |standard       |failed              |2024-01-31        |2021-06-14                        |(505) 210-3927        |failed                |
# |1f789e7e-82f9-46e0-85dd-f82656f33c18|03:59:06             |2.59         |CUST_0378  |joseph.ramirez@gmail.com      |Joseph             |Ramirez           |18          |M              |San Diego          |CA            |PRD_485   |Organic Valley Bakery Sport     |Groceries       |Bakery             |Organic Valley|22.36       |33.03             |WH_008      |Los Angeles   |CA             |US               |9               |35.78     |322.02    |33.67          |1.7             |  SAVE19         |apple_pay                  |false         |0               |203 Elm Dr            |Apt 670|Apt 670_alt   |San Diego    |CA            |92105       |US              |express        |pending             |2024-03-25        |2023-04-17                        |(846) 821-1515        |pending               |
# |18297cb5-6506-4995-b2c4-a8e50676e8e1|03:50:18             |1.99         |CUST_0458  |christopher.davis@gmail.com   |Christopher        |Davis             |39          |Other          |Baltimore          |MD            |PRD_385   |Spalding Nutrition Sport        |Sports          |Nutrition          |Spalding      |122.33      |190.83            |WH_010      |Los Angeles   |CA             |US               |10              |212.94    |2129.4    |9.39           |1.4.0.0         |SAVE43           |paypal                     |true          |true            |6440 Cedar Ave        |Apt 991|Apt 991_alt   |Baltimore    |MD            |21204       |US              |overnight      |pending             |2024-03-07        |2022-01-30                        |(551) 555-8928        |pending               |
# |15381d3d-6eef-4f77-871f-2deacb4eb332|11:56:26             |9.54         |CUST_0554  |daniel.brown@gmail.com        |Danizl             |Brown             |50          |M              |Seattle            |WA            |PRD_192   |Puma Formal Wear Deluxe         |Apparel         |Formal Wear        |Puma          |92.59       |160.5             |WH_005      |New York      |NY             |US               |9               |155.83    |1402.47   |10.08.0.0      |3.1             |  SAVE6          |paypal                     |pending       |pending         |2591 Main St          |Apt 52                |Austin       |TX            |78704       |US              |overnight      |pending             |2024-02-08        |2023-03-20                        |(814) 759-1082        |failed                |
# |f4498080-fc3a-43d2-b21f-b7cb101fa3c0|20:31:36             |5.99         |CUST_0852  |paul.johnson@gmail.com        |Paul               |Johnson           |56          |F              |Los Angeles        |CA            |PRD_388   |Nike Nutrition Premium          |Sports          |Nutrition          |Nike          |228.37      |406.0             |WH_040      |San Diego     |CA             |US               |10              |469.13    |4691.3    |10.43          |10.5            |S@VE26           |credit_card                |1             |1               |4148 Elm Dr           |Apt 530               |Los Angeles  |CA            |90211       |US              |overnight      |pending             |2024-01-23        |2023-01-01                        |(734) 959-5169        |failed                |
# +------------------------------------+---------------------+-------------+-----------+------------------------------+-------------------+------------------+------------+---------------+-------------------+--------------+----------+--------------------------------+----------------+-------------------+--------------+------------+------------------+------------+--------------+---------------+-----------------+----------------+----------+----------+---------------+----------------+-----------------+---------------------------+--------------+----------------+----------------------+----------------------+-------------+--------------+------------+----------------+---------------+--------------------+------------------+----------------------------------+----------------------+----------------------+
# only showing top 20 rows
#
# ['success', 'failed', 'pending', None]

# %% [markdown]
# ### Clean payment method
